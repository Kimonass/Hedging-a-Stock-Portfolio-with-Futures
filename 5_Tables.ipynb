# %% [markdown]
# ###**Tables**

# %%
stock_prices
# Out:
# Stock       EUROB.AT     HTO.AT  INKAT.AT  INLOT.AT  KRI.AT  LAMDA.AT  \
# Date
# 2022-08-09    0.9400  16.860001  1.934412  0.606404    5.88     6.065
# 2022-08-10    0.9600  17.100000  1.908734  0.621075    6.08     6.250
# 2022-08-11    0.9600  16.969999  1.913013  0.596624    6.00     6.340
# 2022-08-12    0.9600  16.540001  1.925852  0.586843    5.96     6.290
# 2022-08-16    0.9840  16.830000  1.900174  0.606404    6.00     6.375
# ...              ...        ...       ...       ...     ...       ...
# 2024-08-05    1.8885  14.030000  4.830000  1.110000   10.50     6.900
# 2024-08-06    1.9300  14.800000  4.920000  1.108000   10.80     6.950
# 2024-08-07    1.9795  14.700000  4.960000  1.124000   11.05     7.140
# 2024-08-08    1.9915  14.470000  5.030000  1.124000   11.15     7.090
# 2024-08-09    1.9885  14.410000  5.030000  1.102000   11.40     7.150
#
# Stock        LAVI.AT  OPAP.AT  OTOEL.AT  PPC.AT  PREMIA.AT  TENERGY.AT
# Date
# ...

# %%
index_prices
# Out:
#               Close
# Date
# 2023-06-23  3062.60
# 2023-06-26  2979.96
# 2023-06-27  2980.46
# 2023-06-28  3016.56
# 2023-06-29  3096.70
# ...             ...
# 2024-08-05  3260.81
# 2024-08-06  3333.85
# 2024-08-07  3394.20
# 2024-08-08  3364.32
# 2024-08-09  3365.54
#
# [283 rows x 1 columns]

# %%
stock_returns
# Out:
# Stock       EUROB.AT    HTO.AT  INKAT.AT  INLOT.AT    KRI.AT  LAMDA.AT  \
# Date
# 2022-08-10  0.021053  0.014134 -0.013363  0.023905  0.033448  0.030047
# 2022-08-11  0.000000 -0.007631  0.002239 -0.040165 -0.013245  0.014297
# 2022-08-12  0.000000 -0.025665  0.006689 -0.016530 -0.006689 -0.007918
# 2022-08-16  0.024693  0.017381 -0.013423  0.032789  0.006689  0.013423
# 2022-08-17 -0.000407  0.018835  0.004495 -0.032789  0.029559 -0.011834
# ...              ...       ...       ...       ...       ...       ...
# 2024-08-05 -0.080592 -0.052077 -0.013368 -0.074623 -0.051055 -0.067252
# 2024-08-06  0.021737  0.053429  0.018462 -0.001803  0.028171  0.007220
# 2024-08-07  0.025324 -0.006780  0.008097  0.014337  0.022884  0.026971
# 2024-08-08  0.006044 -0.015770  0.014014  0.000000  0.009009 -0.007027
# 2024-08-09 -0.001508 -0.004155  0.000000 -0.019767  0.022174  0.008427
#
# Stock        LAVI.AT   OPAP.AT  OTOEL.AT    PPC.AT  PREMIA.AT  TENERGY.AT
# Date
# ...

# %%
index_returns
# Out:
#                Close
# Date
# 2023-06-26 -0.027354
# 2023-06-27  0.000168
# 2023-06-28  0.012039
# 2023-06-29  0.026220
# 2023-06-30  0.000633
# ...              ...
# 2024-08-05 -0.067519
# 2024-08-06  0.022152
# 2024-08-07  0.017940
# 2024-08-08 -0.008842
# 2024-08-09  0.000363
#
# [282 rows x 1 columns]

# %%
port_weights
# Out:
#                Value
# Stock
# EUROB.AT    0.110147
# HTO.AT      0.094247
# INKAT.AT    0.077479
# INLOT.AT    0.090489
# KRI.AT      0.090199
# LAMDA.AT    0.089621
# LAVI.AT     0.078346
# OPAP.AT     0.069673
# OTOEL.AT    0.038450
# PPC.AT      0.093958
# PREMIA.AT   0.087019
# TENERGY.AT  0.080370

# %%
rebalanced_returns
# Out:
# Date
# 2023-06-26   -0.025096
# 2023-06-27    0.011202
# 2023-06-28    0.007454
# 2023-06-29    0.016946
# 2023-06-30    0.003615
# 2023-07-03    0.009725
# 2023-07-04    0.010275
# 2023-07-05   -0.000996
# 2023-07-06   -0.011716
# 2023-07-07    0.001880
# 2023-07-10    0.003962
# 2023-07-11    0.024883
# 2023-07-12    0.003737
# 2023-07-13    0.006074
# 2023-07-14    0.004806
# 2023-07-17   -0.004547
# 2023-07-18    0.006582
# 2023-07-19    0.008895
# 2023-07-20   -0.001875
# 2023-07-21   -0.000567
# 2023-07-24   -0.007065
# 2023-07-25    0.002720
# 2023-07-26    0.002751
# 2023-07-27   -0.001512
# 2023-07-28   -0.004387
# 2023-07-31    0.006759
# 2023-08-01   -0.007970
# 2023-08-02   -0.017001
# 2023-08-03    0.008060
# 2023-08-04    0.004864
# 2023-08-07    0.002029
# 2023-08-08   -0.008764
# 2023-08-09   -0.009542
# 2023-08-10   -0.003886
# Name: Value, dtype: float64

# %%
port_quantity
# Out:
# Stock
# EUROB.AT       6971.328925
# HTO.AT          668.892825
# INKAT.AT       2515.552010
# INLOT.AT      14685.362125
# KRI.AT         1071.247021
# LAMDA.AT       1296.975427
# LAVI.AT       11003.651494
# OPAP.AT         450.957934
# OTOEL.AT        297.140659
# PPC.AT          917.558614
# PREMIA.AT      6592.348223
# TENERGY.AT      461.366244
# Name: Value, dtype: float64

# %%
port_equity
# Out:
# Date
# 2023-08-10     99999.800000
# 2023-08-11     98259.648271
# 2023-08-14     97898.632337
# 2023-08-16     98088.974846
# 2023-08-17     98538.480604
#                   ...
# 2024-08-05    115498.287277
# 2024-08-06    118029.120726
# 2024-08-07    119947.152841
# 2024-08-08    119719.396709
# 2024-08-09    120074.325205
# Name: Equity, Length: 249, dtype: float64

# %%
port_ret
# Out:
#             Portfolio
# Date
# 2023-06-26  -0.025096
# 2023-06-27   0.011202
# 2023-06-28   0.007454
# 2023-06-29   0.016946
# 2023-06-30   0.003615
# ...               ...
# 2024-08-05  -0.057634
# 2024-08-06   0.021676
# 2024-08-07   0.016120
# 2024-08-08  -0.001901
# 2024-08-09   0.002960
#
# [282 rows x 1 columns]
